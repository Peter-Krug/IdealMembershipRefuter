# %%
import cvc5
import tempfile
import subprocess
import re

# %%
import cvc5
from cvc5 import Kind

solver = cvc5.Solver()
solver.setOption("produce-models", "true");
realSort = solver.getRealSort();
intSort = solver.getIntegerSort();

x = solver.mkConst(realSort, "x");
y = solver.mkConst(realSort, "y");
a = solver.mkConst(intSort, "a");
b = solver.mkConst(intSort, "b");

zero = solver.mkReal(0);
one = solver.mkReal(1)
                    
xPlusY = solver.mkTerm(Kind.ADD, x, y);
xTimesY = solver.mkTerm(Kind.MULT, x, y);
                    
constraint1 = solver.mkTerm(Kind.LT, zero, x);
constraint2 = solver.mkTerm(Kind.LT, zero, y);
constraint3 = solver.mkTerm(Kind.LT, xPlusY, one);
constraint4 = solver.mkTerm(Kind.EQUAL, x, y);

solver.assertFormula(constraint1);
solver.assertFormula(constraint2);
solver.assertFormula(constraint3);
solver.assertFormula(constraint4);

r1 = solver.checkSat();

print("result: ", r1)
xVal = solver.getValue(x);
yVal = solver.getValue(y);

print(xVal)

xPy = xVal.getRealValue();
yPy = yVal.getRealValue();

print(xPy)
# Out:
# result:  sat
# (/ 1 8)
# 1/8

# %%
R.<x,y> = PolynomialRing(RR)
polys = [x^2 + y^2 - 1, x*y - 1]
print(solve_with_cvc5_python_api(polys, list(polys[0].parent().gens())))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 3
#       1 R = PolynomialRing(RR, names=('x', 'y',)); (x, y,) = R._first_ngens(2)
#       2 polys = [x**Integer(2) + y**Integer(2) - Integer(1), x*y - Integer(1)]
# ----> 3 print(solve_with_cvc5_python_api(polys, list(polys[Integer(0)].parent().gens())))
#
# Cell In[21], line 39, in solve_with_cvc5_python_api(polynomials, variables)
#      37 # Assert equations equal to zero
#      38 for p in polynomials:
# ---> 39     term = polynomial_to_term(p)
#      40     zero = solver.mkReal("0")
#      41     eq = solver.mkTerm(Kind.EQUAL, [term, zero])
#
# Cell In[21], line 18, in solve_with_cvc5_python_api.<locals>.polynomial_to_term(expr)
#      16 if expr.is_constant():
#      17     return solver.mkReal(str(float(expr)))
# ---> 18 elif expr.operator() is None:
#      19     return var_map[expr]  # variable
#      20 else:
#
# File /ext/sage/10.6/src/sage/structure/element.pyx:495, in sage.structure.element.Element.__getattr__()
#     493         AttributeError: 'LeftZeroSemigroup_with_category.element_class' object has no attribute 'blah_blah'...
#     494     """
# --> 495     return self.getattr_from_category(name)
#     496
#     497 cdef getattr_from_category(self, name):
#
# File /ext/sage/10.6/src/sage/structure/element.pyx:508, in sage.structure.element.Element.getattr_from_category()
#     506     else:
#     507         cls = P._abstract_element_class
# --> 508     return getattr_from_other_class(self, cls, name)
#     509
#     510 def __dir__(self):
#
# File /ext/sage/10.6/src/sage/cpython/getattr.pyx:363, in sage.cpython.getattr.getattr_from_other_class()
#     361     dummy_error_message.cls = type(self)
#     362     dummy_error_message.name = name
# --> 363     raise AttributeError(dummy_error_message)
#     364 attribute = <object>attr
#     365 # Check for a descriptor (__get__ in Python)
#
# AttributeError: 'MPolynomial_polydict' object has no attribute 'operator'

# %%
cvc5 --version
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 cvc5 --version
#
# TypeError: bad operand type for unary -: 'function'
